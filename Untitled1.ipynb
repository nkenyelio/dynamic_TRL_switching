# %%
# !pip install ipywidgets --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host=files.pythonhosted.org
# Out:
# Requirement already satisfied: ipywidgets in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: decorator in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# !pip install nvidia-tensorrt
# Out:
# Collecting nvidia-tensorrt
#   Downloading nvidia_tensorrt-99.0.0-py3-none-manylinux_2_17_x86_64.whl.metadata (596 bytes)
# Collecting tensorrt (from nvidia-tensorrt)
#   Downloading tensorrt-10.5.0.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorrt-cu12==10.5.0 (from tensorrt->nvidia-tensorrt)
#   Downloading tensorrt-cu12-10.5.0.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Downloading nvidia_tensorrt-99.0.0-py3-none-manylinux_2_17_x86_64.whl (17 kB)
# Building wheels for collected packages: tensorrt, tensorrt-cu12
#   Building wheel for tensorrt (setup.py) ... done
#   Created wheel for tensorrt: filename=tensorrt-10.5.0-py2.py3-none-any.whl size=16341 sha256=16472d2c867314868fb72c62490285b7dcb45a048006f6a875be99c9e94ab7cd
#   Stored in directory: /home/usnlab/.cache/pip/wheels/41/08/0c/9228f0e3796130e4426fe106941da6c4a32f2272fd8d2a3d2d
#   Building wheel for tensorrt-cu12 (setup.py) ... done
#   Created wheel for tensorrt-cu12: filename=tensorrt_cu12-10.5.0-py2.py3-none-any.whl size=17555 sha256=29130889da3518af3b9bb012fa4b392f526b612878ac36b0df1a48603f1548d3
#   Stored in directory: /home/usnlab/.cache/pip/wheels/c4/02/65/8f71fda16140283b14de9d6340f00bdbc395c56de93e8d67ac
# Successfully built tensorrt tensorrt-cu12
# Installing collected packages: tensorrt-cu12, tensorrt, nvidia-tensorrt
# Successfully installed nvidia-tensorrt-99.0.0 tensorrt-10.5.0 tensorrt-cu12-10.5.0

# %%
# !pip install torch-tensorrt
# Out:
# Collecting torch-tensorrt
#   Downloading torch_tensorrt-2.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_34_x86_64.whl.metadata (16 kB)
# Collecting torch<2.5.0,>=2.4.0 (from torch-tensorrt)
#   Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting tensorrt==10.1.0 (from torch-tensorrt)
#   Downloading tensorrt-10.1.0.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorrt-cu12-bindings==10.1.0 (from torch-tensorrt)
#   Downloading tensorrt_cu12_bindings-10.1.0-cp311-none-manylinux_2_17_x86_64.whl.metadata (627 bytes)
# Collecting tensorrt-cu12-libs==10.1.0 (from torch-tensorrt)
#   Downloading tensorrt_cu12_libs-10.1.0.tar.gz (630 bytes)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging>=23 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch-tensorrt) (23.2)
# Requirement already satisfied: numpy in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch-tensorrt) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.7.0 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch-tensorrt) (4.9.0)
# Requirement already satisfied: tensorrt-cu12 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from tensorrt==10.1.0->torch-tensorrt) (10.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from tensorrt-cu12-libs==10.1.0->torch-tensorrt) (12.6.77)
# Requirement already satisfied: filelock in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch<2.5.0,>=2.4.0->torch-tensorrt) (3.13.1)
# Requirement already satisfied: sympy in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch<2.5.0,>=2.4.0->torch-tensorrt) (1.12)
# Requirement already satisfied: networkx in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch<2.5.0,>=2.4.0->torch-tensorrt) (3.1)
# Requirement already satisfied: jinja2 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch<2.5.0,>=2.4.0->torch-tensorrt) (3.1.3)
# Requirement already satisfied: fsspec in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from torch<2.5.0,>=2.4.0->torch-tensorrt) (2024.3.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12 (from tensorrt-cu12-libs==10.1.0->torch-tensorrt)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch<2.5.0,>=2.4.0->torch-tensorrt)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from jinja2->torch<2.5.0,>=2.4.0->torch-tensorrt) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages (from sympy->torch<2.5.0,>=2.4.0->torch-tensorrt) (1.3.0)
# Downloading torch_tensorrt-2.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_34_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 5.8 MB/s eta 0:00:0000:0100:01m
# Downloading tensorrt_cu12_bindings-10.1.0-cp311-none-manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 3.3 MB/s eta 0:00:00:00:010:03m
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 5.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 9.7 MB/s eta 0:00:00ta 0:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:0000:01m00:02
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.1 MB/s eta 0:00:0000:01m00:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.9 MB/s eta 0:00:00:00:010:01m
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.7 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 10.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: tensorrt, tensorrt-cu12-libs
#   Building wheel for tensorrt (setup.py) ... done
#   Created wheel for tensorrt: filename=tensorrt-10.1.0-py2.py3-none-any.whl size=16334 sha256=ea78f0d5a24884531243644a21c327ac7caebcfd5cfb36ff1539bf6b14a6e97c
#   Stored in directory: /home/usnlab/.cache/pip/wheels/0c/33/af/43309e7a6f08d95ab1c74c2816f5a2b6a14a98fa3f3afa5590
#   Building wheel for tensorrt-cu12-libs (pyproject.toml) ... done
#   Created wheel for tensorrt-cu12-libs: filename=tensorrt_cu12_libs-10.1.0-py2.py3-none-manylinux_2_17_x86_64.whl size=1056270840 sha256=1ad13c26b3f441267a746df6859e44eb0e8da78d4382458d1fd2eb7675abd49f
#   Stored in directory: /home/usnlab/.cache/pip/wheels/38/b3/dc/8ce867ba022fb9f354fcc7fee92f52cc6d1197a674a13afb50
# Successfully built tensorrt tensorrt-cu12-libs
# Installing collected packages: tensorrt-cu12-bindings, triton, tensorrt, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tensorrt-cu12-libs, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torch-tensorrt
#   Attempting uninstall: tensorrt-cu12-bindings
#     Found existing installation: tensorrt-cu12-bindings 10.5.0
#     Uninstalling tensorrt-cu12-bindings-10.5.0:
#       Successfully uninstalled tensorrt-cu12-bindings-10.5.0
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: tensorrt
#     Found existing installation: tensorrt 10.5.0
#     Uninstalling tensorrt-10.5.0:
#       Successfully uninstalled tensorrt-10.5.0
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: tensorrt-cu12-libs
#     Found existing installation: tensorrt-cu12-libs 10.5.0
#     Uninstalling tensorrt-cu12-libs-10.5.0:
#       Successfully uninstalled tensorrt-cu12-libs-10.5.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 tensorrt-10.1.0 tensorrt-cu12-bindings-10.1.0 tensorrt-cu12-libs-10.1.0 torch-2.4.1 torch-tensorrt-2.4.0 triton-3.0.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch_tensorrt

from torch.utils.tensorboard import SummaryWriter

import pytorch_quantization
from pytorch_quantization import nn as quant_nn
from pytorch_quantization import quant_modules
from pytorch_quantization.tensor_quant import QuantDescriptor
from pytorch_quantization import calib
from tqdm import tqdm

print(pytorch_quantization.__version__)

import os
import sys
sys.path.insert(0, "../examples/int8/training/vgg16")
from vgg16 import vgg16
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 8
#       6 import torchvision.transforms as transforms
#       7 import torchvision.datasets as datasets
# ----> 8 import torch_tensorrt
#      10 from torch.utils.tensorboard import SummaryWriter
#      12 import pytorch_quantization
#
# File ~/miniconda3/envs/torch/lib/python3.11/site-packages/torch_tensorrt/__init__.py:114
#     110         assert ENABLED_FEATURES.torch_tensorrt_runtime
#     111         torch.ops.load_library(linked_file_runtime_full_path)
# --> 114 _register_with_torch()
#     116 from torch_tensorrt._Device import Device  # noqa: F401
#     117 from torch_tensorrt._enums import (  # noqa: F401
#     118     DeviceType,
#     119     EngineCapability,
#     120     dtype,
#     121     memory_format,
#     122 )
#
# File ~/miniconda3/envs/torch/lib/python3.11/site-packages/torch_tensorrt/__init__.py:107, in _register_with_torch()
#     105     assert ENABLED_FEATURES.torchscript_frontend
#     106     assert ENABLED_FEATURES.torch_tensorrt_runtime
# --> 107     torch.ops.load_library(linked_file_full_path)
#     109 elif os.path.isfile(linked_file_runtime_full_path):
#     110     assert ENABLED_FEATURES.torch_tensorrt_runtime
#
# File ~/miniconda3/envs/torch/lib/python3.11/site-packages/torch/_ops.py:933, in load_library(self, path)
#     922     if torch._C._dispatch_kernel_for_dispatch_key_is_fallthrough(
#     923         self.name(), dispatch_key
#     924     ):
#     925         return self._dispatch_in_python(
#     926             args, kwargs, fallthrough_keys + [dispatch_key]
#     927         )
#     929     raise RuntimeError(
#     930         f"Torchbind op {self} received a FakeScriptObject input when dispatching {handler}."
#     931         f" but no python implementation is found."
#     932         f" Please file an issue on this when you encounter this error."
# --> 933         f" This error can happen when you export or compile the model."
#     934         f" It can still happpen even if a C++ implementation for {dispatch_key}. "
#     935         f" has been registered. That's because FakeScriptObject purely lives in python and cannot work "
#     936         f" with a C++ implementation."
#     937     )
#     939 assert isinstance(handler, Callable)  # type: ignore[arg-type]
#     940 return handler(*args, **kwargs)
#
# File ~/miniconda3/envs/torch/lib/python3.11/ctypes/__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 self._FuncPtr = _FuncPtr
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#     378     self._handle = handle
#
# OSError: /home/usnlab/miniconda3/envs/torch/lib/python3.11/site-packages/torch_tensorrt/lib/libtorchtrt.so: undefined symbol: _ZNK3c105Error4whatEv
